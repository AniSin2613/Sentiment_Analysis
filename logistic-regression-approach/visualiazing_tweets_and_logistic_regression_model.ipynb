# %% [markdown]
# ## **Visualizing Tweets and the Logistic Regression Model**

# %% [markdown]
# **Objectives:** Visualize and interpret the logistic regression model.
#
# **Steps:**
#
# * Plot tweets in a scatter plot using their positive and negative sums.
#
# * Plot the output of the logistic regression model in the same plot as a solid line.

# %% [markdown]
# ### **Import the required libraries**

# %%
# !cp '/content/drive/My Drive/Colab Notebooks/utils.py' '/content'

# %%
import nltk
from os import getcwd
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples
import matplotlib.pyplot as plt

from utils import process_tweet, build_freqs

# %% [markdown]
# ### **Load the NLTK sample datatset**

# %%
# download the Twitter sample dataset from NLTK
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
# load positive and negative tweets
pos_tweets = twitter_samples.strings('positive_tweets.json')
neg_tweets = twitter_samples.strings('negative_tweets.json')

# concatenate all the tweets into single list
tweets = pos_tweets + neg_tweets
# add labels (1 for positive; 0 for negative)
labels = np.append(np.ones((len(pos_tweets), 1)), 
                   np.zeros((len(neg_tweets), 1)),
                   axis = 0)

# %%
# split the data into train and test
train_pos = pos_tweets[:4000]
train_neg = neg_tweets[:4000]

train_x = train_pos + train_neg
print('Number of tweets in train data:', len(train_x))
# Out:
# Number of tweets in train data: 8000
